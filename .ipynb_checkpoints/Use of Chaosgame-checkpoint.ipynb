# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import chaosgame as c

# %%
c.chaosgame(0.5)

# %%
c.chaosgamen(1.5,3,20000)

# %%
v1=c.bmulticondatachaosgamen(np.linspace(0,2,50),np.sin(np.arange(0,3000,10,dtype='float64')))

# %%
v1=c.multicondatachaosgamen(np.linspace(0,1,50),np.sin(np.arange(0,3000,2,dtype='float64'))*np.sin(0.5*np.arange(0,3000,2,dtype='float64')))

# %%
v1,v2=c.conpdatachaosgamen(0.5,np.sin(np.arange(0,300,1.4,dtype='float64')))

# %%
v1,v2=c.bconpdatachaosgamen(2,np.sin(np.arange(0,350,0.8,dtype='float64')))

# %%
v1=c.multicondatachaosgamen(np.linspace(0.1,1.9,10),(1+np.arange(0,1000,1)*5000*np.sin(np.arange(0,1000,1))))

# %%
v1,v2=c.condatachaosgamen(2,(1+np.arange(0,6000,1)*5000*np.sin(np.arange(0,6000,1))))

# %%
v1,v2=c.new2condatachaosgamen((1+np.arange(0,19000,1)*5000*np.sin(np.arange(0,19000,1))))

# %%
plt.scatter(v1,v2,s=0.5)
plt.xlim([np.min(v1),np.max(v1)])
plt.ylim([0.6,1])
# Out:
# (0.6, 1)
